# %% [markdown]
# ### Weather Analysis for 7 days

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("../data/bremen_forecast.csv", parse_dates=["time"], index_col="time")

# PLot temperature
df["temperature_2m"].plot(figsize=(12,4), title="Temperature (2m) in Bremen", grid=True)
plt.ylabel("°C")
plt.show()

# Plot wind speed
df["wind_speed_10m"].plot(figsize=(12, 4), title="Wind Speed (10m) in Bremen", grid=True)
plt.ylabel("m/s")
plt.show()

# Plot solar radiation
plt.figure(figsize=(12, 4))
df["shortwave_radiation"].plot(label="Shortwave Radiation", color="orange")
plt.title("Solar Radiation Forecast in Bremen")
plt.ylabel("W/m²")
plt.xlabel("Time")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### June weather analysis

# %%
# Load data
df_historical = pd.read_csv("../data/bremen_june_2025.csv", parse_dates=["time"], index_col="time")

# Preview
df.head()
# Out:
#                      temperature_2m  wind_speed_10m  shortwave_radiation
# time
# 2025-07-10 00:00:00            15.2             6.4                  0.0
# 2025-07-10 01:00:00            14.7             6.0                  0.0
# 2025-07-10 02:00:00            14.0             6.4                  0.0
# 2025-07-10 03:00:00            13.5             6.0                  0.0
# 2025-07-10 04:00:00            13.3             5.4                  0.0

# %%
import matplotlib.pyplot as plt

df_historical.plot(subplots=True, figsize=(14, 8), title="Hourly Weather in Bremen - June 2025", grid=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Basic overview of the data

# %%
print("Shape:", df_historical.shape)
print("\nMissing values:\n", df_historical.isna().sum())
print("\nSummary statistics:\n", df_historical.describe())
# Out:
# Shape: (720, 3)
#
# Missing values:
#  temperature_2m         0
# wind_speed_10m         0
# shortwave_radiation    0
# dtype: int64
#
# Summary statistics:
#         temperature_2m  wind_speed_10m  shortwave_radiation
# count      720.000000      720.000000           720.000000
# mean        17.313611       12.896806           246.222222
# std          4.341504        5.708180           261.881144
# min          7.900000        0.400000             0.000000
# 25%         14.300000        8.575000             0.000000
# 50%         17.200000       12.850000           168.500000
# 75%         19.900000       16.700000           439.000000
# max         31.000000       33.100000           861.000000

# %%
df_daily = df.resample("D").mean()

df_daily.plot(figsize=(14, 5), title="Daily Averages - June 2025", grid=True)
plt.ylabel("Mean Value")
plt.show()

# %%
import seaborn as sns

sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix - Hourly Data")
plt.show()
